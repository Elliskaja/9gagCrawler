# %%
import pandas as pd
import os
#from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('id_and_votes.xlsx')
df.head()
# Out:
#                   id  comment_count upvotes downvotes       category
# 0  jsid-post-a1PQZ7v             47      43        51      anti_anti
# 1  jsid-post-a1PRXVb              9      22        31     narra_anti
# 2  jsid-post-a2Kox39            761     10K       761  activist_anti
# 3  jsid-post-a2KZvXD             91     150       267      anti_anti
# 4  jsid-post-a3ZK7n7            138     156       124   sciency_anti

# %%
a = "10K"
b = "2.6K"
c = "123"

def xK_votes_to_int(s):
    if type(s) == int:
        return s
    if "K" in s:
        s = s[:-1]
        result = int(float(s) * 1000)
    else:
        result = int(s)
    return result

# %%
df['upvotes'] = df['upvotes'].apply(xK_votes_to_int)
df['downvotes'] = df['downvotes'].apply(xK_votes_to_int)
df['comment_count'] = df['comment_count'].apply(xK_votes_to_int)
df_new = df['category'].str.split("_", n = 1, expand = True)
df['category_content'] = df_new[0]
df['category_orientation'] = df_new[1]
df.head()
# Out:
#                   id  comment_count  upvotes  downvotes       category  \
# 0  jsid-post-a1PQZ7v             47       43         51      anti_anti
# 1  jsid-post-a1PRXVb              9       22         31     narra_anti
# 2  jsid-post-a2Kox39            761    10000        761  activist_anti
# 3  jsid-post-a2KZvXD             91      150        267      anti_anti
# 4  jsid-post-a3ZK7n7            138      156        124   sciency_anti
#
#    vote_ratio category_content category_orientation
# 0          -8             anti                 anti
# 1          -9            narra                 anti
# 2        9239         activist                 anti
# 3        -117             anti                 anti
# 4          32          sciency                 anti

# %%
df['vote_ratio'] = df['upvotes'] - df['downvotes']
df.head()
# Out:
#                   id  comment_count  upvotes  downvotes       category  \
# 0  jsid-post-a1PQZ7v             47       43         51      anti_anti
# 1  jsid-post-a1PRXVb              9       22         31     narra_anti
# 2  jsid-post-a2Kox39            761    10000        761  activist_anti
# 3  jsid-post-a2KZvXD             91      150        267      anti_anti
# 4  jsid-post-a3ZK7n7            138      156        124   sciency_anti
#
#    vote_ratio
# 0          -8
# 1          -9
# 2        9239
# 3        -117
# 4          32

# %%
fig = plt.figure(figsize = (10,5))
#plt.gca().set_ylim(-100, 100)
sns.stripplot(data = df, x = 'category', y = 'vote_ratio')
plt.xticks(rotation = 45, ha = 'right')
print()

# %%
df_temp = df.copy()
df_temp['downvotes_inverse'] = -df['downvotes']
df_temp = df_temp.sort_values(by = "upvotes", ascending = False)
min_upvotes = 150
df_temp = df_temp[df_temp['upvotes'] >= min_upvotes]

upvote_color = 'blue'
downvote_color = 'red'
comment_color = 'green'

fig = plt.figure(figsize = (20,10))
#plt.gca().set_xlim(0, 20)
sns.barplot(data = df_temp, x = 'id', y = 'upvotes', color = upvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'downvotes_inverse', color = downvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'comment_count', color = comment_color)
plt.xticks(rotation = 90, ha = 'center')
print()

# %%
df_temp = df.copy()
df_temp['downvotes_inverse'] = -df['downvotes']
df_temp = df_temp.sort_values(by = "upvotes", ascending = False)
min_upvotes = 150
df_temp = df_temp[df_temp['upvotes'] <= min_upvotes]

upvote_color = 'blue'
downvote_color = 'red'
comment_color = 'green'

fig = plt.figure(figsize = (20,10))
#plt.gca().set_xlim(0, 20)
sns.barplot(data = df_temp, x = 'id', y = 'upvotes', color = upvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'downvotes_inverse', color = downvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'comment_count', color = comment_color)
plt.xticks(rotation = 90, ha = 'center')
print()

# %%
df_temp = df.copy()
df_temp['downvotes_inverse'] = -df['downvotes']
df_temp = df_temp.sort_values(by = "upvotes", ascending = False)
min_upvotes = 150
df_temp = df_temp[df_temp['upvotes'] >= min_upvotes]

upvote_color = 'blue'
downvote_color = 'red'
comment_color = 'green'

fig = plt.figure(figsize = (20,10))
#plt.gca().set_xlim(0, 20)
sns.barplot(data = df_temp, x = 'id', y = 'upvotes', hue = 'category', dodge = False, palette = 'turbo')
sns.barplot(data = df_temp, x = 'id', y = 'downvotes_inverse', color = downvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'comment_count', color = comment_color)
plt.xticks(rotation = 90, ha = 'center')
print()

# %%
df_temp = df.copy()
df_temp['downvotes_inverse'] = -df['downvotes']
df_temp = df_temp.sort_values(by = "upvotes", ascending = False)
min_upvotes = 150
df_temp = df_temp[df_temp['upvotes'] >= min_upvotes]

upvote_color = 'blue'
downvote_color = 'red'
comment_color = 'green'

fig = plt.figure(figsize = (20,10))
#plt.gca().set_xlim(0, 20)
sns.barplot(data = df_temp, x = 'id', y = 'upvotes', hue = 'category_content', dodge = False, palette = 'turbo')
sns.barplot(data = df_temp, x = 'id', y = 'downvotes_inverse', color = downvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'comment_count', color = comment_color)
plt.xticks(rotation = 90, ha = 'center')
print()

# %%
df_temp = df.copy()
df_temp['downvotes_inverse'] = -df['downvotes']
df_temp = df_temp.sort_values(by = "upvotes", ascending = False)
min_upvotes = 150
df_temp = df_temp[df_temp['upvotes'] >= min_upvotes]

upvote_color = 'blue'
downvote_color = 'red'
comment_color = 'green'

fig = plt.figure(figsize = (20,10))
#plt.gca().set_xlim(0, 20)
sns.barplot(data = df_temp, x = 'id', y = 'upvotes', hue = 'category_orientation', dodge = False, palette = 'turbo')
sns.barplot(data = df_temp, x = 'id', y = 'downvotes_inverse', color = downvote_color)
sns.barplot(data = df_temp, x = 'id', y = 'comment_count', color = comment_color)
plt.xticks(rotation = 90, ha = 'center')
print()
